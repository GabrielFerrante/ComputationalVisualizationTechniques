# %%
# %matplotlib inline
import seaborn as sns

anscombe = sns.load_dataset("anscombe")

sns.lmplot(x="x", y="y", col="dataset", hue="dataset", data=anscombe,
           col_wrap=2, ci=None, palette="muted", height=4,
           scatter_kws={"s": 50, "alpha": 1})

# %%
import pandas as pd
import numpy as np

groups = anscombe.groupby("dataset")
display(groups.agg([np.mean, np.std, np.cov, np.sum]).T)
# Out:
# dataset          I         II        III         IV
# x mean    9.000000   9.000000   9.000000   9.000000
#   std     3.316625   3.316625   3.316625   3.316625
#   cov    11.000000  11.000000  11.000000  11.000000
#   sum    99.000000  99.000000  99.000000  99.000000
# y mean    7.500909   7.500909   7.500000   7.500909
#   std     2.031568   2.031657   2.030424   2.030579
#   cov     4.127269   4.127629   4.122620   4.123249
#   sum    82.510000  82.510000  82.500000  82.510000
